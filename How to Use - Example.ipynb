# %%
## Installation
#!pip install scorecard_generator==2.1.5
#https://pypi.org/project/scorecard-generator/

# %%
## Load Package
from scorecard_generator import scorecard

# %%
## Load Data and Train Data
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# Generate a binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_classes=2, random_state=42)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Feature names for the simulated dataset
feature_names = [f'Feature{i}' for i in range(X.shape[1])]

# %%
# Train Logistic Regression
logistic_model = LogisticRegression(max_iter=10000)
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest
random_forest_model = RandomForestClassifier(n_estimators=100)
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Train Gradient Boosting
gradient_boosting_model = GradientBoostingClassifier(n_estimators=100)
gradient_boosting_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
from sklearn.svm import SVC

# Train Support Vector Classifier with Linear Kernel
svc_model = SVC(kernel='linear', probability=True)
svc_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Train Elastic Net Logistic Regression
elastic_net_model = make_pipeline(StandardScaler(), SGDClassifier(loss='log_loss', penalty='elasticnet', l1_ratio=0.5))
elastic_net_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdclassifier',
#                  SGDClassifier(l1_ratio=0.5, loss='log_loss',
#                                penalty='elasticnet'))])

# %%
from sklearn.naive_bayes import GaussianNB

# Train Naive Bayes
naive_bayes_model = GaussianNB()
naive_bayes_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.tree import DecisionTreeClassifier

# Train Decision Tree
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Generate the scorecard with the best threshold highlighted
feature_score, total_score = scorecard(logistic_model, feature_names, X_test, y_test, min_score=300, max_score=850)

# %%
## Important feature weights
feature_score
# Out:
#    Feature Name  Coefficients  Score - Calculation
# 0      Feature0     -0.452853                 -106
# 1      Feature1      0.131896                   31
# 2      Feature2     -0.741194                 -174
# 3      Feature3      0.067408                   16
# 4      Feature4     -0.051319                  -12
# 5      Feature5     -0.279101                  -65
# 6      Feature6      1.607507                  376
# 7      Feature7     -0.012738                   -3
# 8      Feature8     -0.613603                 -144
# 9      Feature9      0.093784                   22
# 10    Intercept      0.100794                  497

# %%
## Total score
total_score
# Out:
# <style type="text/css">
# #T_5dd8a_row9_col0, #T_5dd8a_row9_col1, #T_5dd8a_row9_col2 {
#   background-color: #132E57;
#   color: white;
# }
# </style>
# <table id="T_5dd8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dd8a_level0_col0" class="col_heading level0 col0" >Threshold</th>
#       <th id="T_5dd8a_level0_col1" class="col_heading level0 col1" >Total Score Bin</th>
#       <th id="T_5dd8a_level0_col2" class="col_heading level0 col2" >Decision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dd8a_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_5dd8a_row0_col0" class="data row0 col0" >0.837712</td>
#       <td id="T_5dd8a_row0_col1" class="data row0 col1" >[850, 850 + error)</td>
#       <td id="T_5dd8a_row0_col2" class="data row0 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_5dd8a_row1_col0" class="data row1 col0" >0.824900</td>
#       <td id="T_5dd8a_row1_col1" class="data row1 col1" >[837 - 850)</td>
#       <td id="T_5dd8a_row1_col2" class="data row1 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_5dd8a_row2_col0" class="data row2 col0" >0.824272</td>
#       <td id="T_5dd8a_row2_col1" class="data row2 col1" >[835 - 837)</td>
#       <td id="T_5dd8a_row2_col2" class="data row2 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_5dd8a_row3_col0" class="data row3 col0" >0.736818</td>
#       <td id="T_5dd8a_row3_col1" class="data row3 col1" >[715 - 835)</td>
#       <td id="T_5dd8a_row3_col2" class="data row3 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_5dd8a_row4_col0" class="data row4 col0" >0.694966</td>
#       <td id="T_5dd8a_row4_col1" class="data row4 col1" >[666 - 715)</td>
#       <td id="T_5dd8a_row4_col2" class="data row4 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_5dd8a_row5_col0" class="data row5 col0" >0.671729</td>
#       <td id="T_5dd8a_row5_col1" class="data row5 col1" >[641 - 666)</td>
#       <td id="T_5dd8a_row5_col2" class="data row5 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_5dd8a_row6_col0" class="data row6 col0" >0.667046</td>
#       <td id="T_5dd8a_row6_col1" class="data row6 col1" >[636 - 641)</td>
#       <td id="T_5dd8a_row6_col2" class="data row6 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row7" class="row_heading level0 row7" >14</th>
#       <td id="T_5dd8a_row7_col0" class="data row7 col0" >0.654985</td>
#       <td id="T_5dd8a_row7_col1" class="data row7 col1" >[624 - 636)</td>
#       <td id="T_5dd8a_row7_col2" class="data row7 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_5dd8a_row8_col0" class="data row8 col0" >0.593311</td>
#       <td id="T_5dd8a_row8_col1" class="data row8 col1" >[562 - 624)</td>
#       <td id="T_5dd8a_row8_col2" class="data row8 col2" >Approve</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_5dd8a_row9_col0" class="data row9 col0" >0.536416</td>
#       <td id="T_5dd8a_row9_col1" class="data row9 col1" >[508 - 562)</td>
#       <td id="T_5dd8a_row9_col2" class="data row9 col2" >Unsure</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_5dd8a_row10_col0" class="data row10 col0" >0.513743</td>
#       <td id="T_5dd8a_row10_col1" class="data row10 col1" >[486 - 508)</td>
#       <td id="T_5dd8a_row10_col2" class="data row10 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row11" class="row_heading level0 row11" >10</th>
#       <td id="T_5dd8a_row11_col0" class="data row11 col0" >0.513285</td>
#       <td id="T_5dd8a_row11_col1" class="data row11 col1" >[486 - 508)</td>
#       <td id="T_5dd8a_row11_col2" class="data row11 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row12" class="row_heading level0 row12" >9</th>
#       <td id="T_5dd8a_row12_col0" class="data row12 col0" >0.512316</td>
#       <td id="T_5dd8a_row12_col1" class="data row12 col1" >[485 - 486)</td>
#       <td id="T_5dd8a_row12_col2" class="data row12 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row13" class="row_heading level0 row13" >8</th>
#       <td id="T_5dd8a_row13_col0" class="data row13 col0" >0.506905</td>
#       <td id="T_5dd8a_row13_col1" class="data row13 col1" >[480 - 485)</td>
#       <td id="T_5dd8a_row13_col2" class="data row13 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row14" class="row_heading level0 row14" >7</th>
#       <td id="T_5dd8a_row14_col0" class="data row14 col0" >0.495671</td>
#       <td id="T_5dd8a_row14_col1" class="data row14 col1" >[470 - 480)</td>
#       <td id="T_5dd8a_row14_col2" class="data row14 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row15" class="row_heading level0 row15" >6</th>
#       <td id="T_5dd8a_row15_col0" class="data row15 col0" >0.460886</td>
#       <td id="T_5dd8a_row15_col1" class="data row15 col1" >[437 - 470)</td>
#       <td id="T_5dd8a_row15_col2" class="data row15 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row16" class="row_heading level0 row16" >5</th>
#       <td id="T_5dd8a_row16_col0" class="data row16 col0" >0.445311</td>
#       <td id="T_5dd8a_row16_col1" class="data row16 col1" >[422 - 437)</td>
#       <td id="T_5dd8a_row16_col2" class="data row16 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row17" class="row_heading level0 row17" >4</th>
#       <td id="T_5dd8a_row17_col0" class="data row17 col0" >0.409562</td>
#       <td id="T_5dd8a_row17_col1" class="data row17 col1" >[388 - 422)</td>
#       <td id="T_5dd8a_row17_col2" class="data row17 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row18" class="row_heading level0 row18" >3</th>
#       <td id="T_5dd8a_row18_col0" class="data row18 col0" >0.387348</td>
#       <td id="T_5dd8a_row18_col1" class="data row18 col1" >[366 - 388)</td>
#       <td id="T_5dd8a_row18_col2" class="data row18 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row19" class="row_heading level0 row19" >2</th>
#       <td id="T_5dd8a_row19_col0" class="data row19 col0" >0.344979</td>
#       <td id="T_5dd8a_row19_col1" class="data row19 col1" >[323 - 366)</td>
#       <td id="T_5dd8a_row19_col2" class="data row19 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row20" class="row_heading level0 row20" >1</th>
#       <td id="T_5dd8a_row20_col0" class="data row20 col0" >0.338780</td>
#       <td id="T_5dd8a_row20_col1" class="data row20 col1" >[317 - 323)</td>
#       <td id="T_5dd8a_row20_col2" class="data row20 col2" >Reject</td>
#     </tr>
#     <tr>
#       <th id="T_5dd8a_level0_row21" class="row_heading level0 row21" >0</th>
#       <td id="T_5dd8a_row21_col0" class="data row21 col0" >0.320612</td>
#       <td id="T_5dd8a_row21_col1" class="data row21 col1" >[300 - 317)</td>
#       <td id="T_5dd8a_row21_col2" class="data row21 col2" >Reject</td>
#     </tr>
#   </tbody>
# </table>
